# %% [markdown]
# ## Install and Import Dependencies

# %%
pip install transformers datasets tensorflow
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from transformers import pipeline, TFAutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset

# %% [markdown]
# ## Load Dataset

# %%
imdb_dataset = load_dataset("imdb", split = "test[:100]")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
imdb_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 100
# })

# %% [markdown]
# #### Prepare data for Sentiment Analysis

# %%
reviews = []
for review in imdb_dataset :
  review_text = review['text']
  reviews.append(review_text)

# %% [markdown]
# ## Defining Pipeline for Sentiment Analysis

# %%
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model = "distilbert-base-uncased-finetuned-sst-2-english",
    framework = "tf"
)

results = sentiment_analyzer(reviews)
# Out:
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# Device set to use 0
# Token indices sequence length is longer than the specified maximum sequence length for this model (532 > 512). Running this sequence through the model will result in indexing errors

# %% [markdown]
# #### Sentiments

# %%
for review, result in zip(reviews, results):
    print("\nReview :", review[:100])
    print("Sentiment :", result['label'])
    print(f"Score:", result['score'])
# Out:
# Review : I love sci-fi and am willing to put up with a lot. Sci-fi movies/TV are usually underfunded, under-a
# Sentiment : NEGATIVE
# Score: 0.999616265296936
#
# Review : Worth the entertainment value of a rental, especially if you like action movies. This one features t
# Sentiment : NEGATIVE
# Score: 0.6170631051063538
#
# Review : its a totally average film with a few semi-alright action sequences that make the plot seem a little
# Sentiment : NEGATIVE
# Score: 0.9997100234031677
#
# Review : STAR RATING: ***** Saturday Night **** Friday Night *** Friday Morning ** Sunday Night * Monday Morn
# Sentiment : NEGATIVE
# Score: 0.995756208896637
#
# Review : First off let me say, If you haven't enjoyed a Van Damme movie since bloodsport, you probably will n
# Sentiment : POSITIVE
# Score: 0.996307373046875
#
# Review : I had high hopes for this one until they changed the name to 'The Shepherd : Border Patrol, the lame
# Sentiment : NEGATIVE
# Score: 0.9966711401939392
#
# Review : Isaac Florentine has made some of the best western Martial Arts action movies ever produced. In part
# Sentiment : NEGATIVE
# Score: 0.9584166407585144
#
# Review : It actually pains me to say it, but this movie was horrible on every level. The blame does not lie e
# Sentiment : NEGATIVE
# Score: 0.9994093179702759
#
# Review : Technically I'am a Van Damme Fan, or I was. this movie is so bad that I hated myself for wasting tho
# Sentiment : NEGATIVE
# Score: 0.9996923208236694
#
# Review : Honestly awful film, bad editing, awful lighting, dire dialog and scrappy screenplay.<br /><br />The
# Sentiment : NEGATIVE
# Score: 0.99977046251297
#
# Review : This flick is a waste of time.I expect from an action movie to have more than 2 explosions and some
# Sentiment : NEGATIVE
# Score: 0.9997914433479309
#
# Review : Blind Date (Columbia Pictures, 1934), was a decent film, but I have a few issues with this film. Fir
# Sentiment : NEGATIVE
# Score: 0.9940081834793091
#
# Review : I first watched this movie back in the mid/late 80's, when I was a kid. We couldn't even get all the
# Sentiment : NEGATIVE
# Score: 0.9997391104698181
#
# Review : I saw the Mogul Video VHS of this. That's another one of those old 1980s distributors whose catalog
# Sentiment : NEGATIVE
# Score: 0.9996107220649719
#
# Review : A group of heirs to a mysterious old mansion find out that they have to live in it as part of a clau
# Sentiment : NEGATIVE
# Score: 0.9997557997703552
#
# Review : Now, I LOVE Italian horror films. The cheesier they are, the better. However, this is not cheesy Ita
# Sentiment : NEGATIVE
# Score: 0.9913800358772278
#
# Review : This cheap, grainy-filmed Italian flick is about a couple of inheritors of a manor in the Italian co
# Sentiment : NEGATIVE
# Score: 0.9960663914680481
#
# Review : I just finished watching this movie and am disappointed to say that I didn't enjoy it a bit. It is s
# Sentiment : NEGATIVE
# Score: 0.9991810917854309
#
# Review : Ben, (Rupert Grint), is a deeply unhappy adolescent, the son of his unhappily married parents. His f
# Sentiment : POSITIVE
# Score: 0.6568292379379272
#
# Review : Every movie I have PPV'd because Leonard Maltin praised it to the skies has blown chunks! Every sing
# Sentiment : NEGATIVE
# Score: 0.9949303269386292
#
# Review : Low budget horror movie. If you don't raise your expectations too high, you'll probably enjoy this l
# Sentiment : POSITIVE
# Score: 0.8982696533203125
#
# Review : Dr Stephens (Micheal Harvey) runs a mental asylum. He has a different approach to the insane. He con
# Sentiment : NEGATIVE
# Score: 0.9977770447731018
#
# Review : The Forgotten (AKA: Don't Look In The Basement) is a very cheaply made and very old looking horror m
# Sentiment : NEGATIVE
# Score: 0.9971417784690857
#
# Review : This movie had a very unique effect on me: it stalled my realization that this movie REALLY sucks! I
# Sentiment : NEGATIVE
# Score: 0.9994034767150879
#
# Review : too bad this movie isn't. While "Nemesis Game" is mildly entertaining, I found it hard to suspend my
# Sentiment : NEGATIVE
# Score: 0.9985180497169495
#
# Review : I of course saw the previews for this at the beginning of some other Lion's Gate extravaganza, so of
# Sentiment : NEGATIVE
# Score: 0.9926362037658691
#
# Review : I gave this a 3 out of a possible 10 stars.<br /><br />Unless you like wasting your time watching an
# Sentiment : NEGATIVE
# Score: 0.9960595369338989
#
# Review : I was looking forward to this movie. Trustworthy actors, interesting plot. Great atmosphere then ???
# Sentiment : NEGATIVE
# Score: 0.9808396100997925
#
# Review : Four things intrigued me as to this film - firstly, it stars Carly Pope (of "Popular" fame), who is
# Sentiment : NEGATIVE
# Score: 0.9941185712814331
#
# Review : <br /><br />Never ever take a film just for its good looking title.<br /><br />Although it all start
# Sentiment : NEGATIVE
# Score: 0.9979615211486816
#
# Review : Lowe returns to the nest after, yet another, failed relationship, to find he's been assigned to jury
# Sentiment : NEGATIVE
# Score: 0.9977018237113953
#
# Review : Seriously, I can't imagine how anyone could find a single flattering thing to say about this movie,
# Sentiment : NEGATIVE
# Score: 0.9996092915534973
#
# Review : I'm the type of guy who loves hood movies from New Jack City to Baby Boy to Killa Season, from the b
# Sentiment : NEGATIVE
# Score: 0.96412593126297
#
# Review : The most positive points in this film were the credits (text style) and some moments in Ice-T's acti
# Sentiment : NEGATIVE
# Score: 0.9950646758079529
#
# Review : I quite enjoyed The Wrecking Crew (1999), which was the last of the three films in this series (the
# Sentiment : NEGATIVE
# Score: 0.9948039650917053
#
# Review : this film has no plot, no good acting, to be honest it has nothing, the same songs play over and ove
# Sentiment : NEGATIVE
# Score: 0.9995680451393127
#
# Review : Beware, My Lovely (1952) Dir: Harry Horner <br /><br />Production: The Filmmakers/RKO Radio Pictures
# Sentiment : NEGATIVE
# Score: 0.9993889331817627
#
# Review : The only reason this movie is not given a 1 (awful) vote is that the acting of both Ida Lupino and R
# Sentiment : POSITIVE
# Score: 0.7335496544837952
#
# Review : Artificial melodrama with a screenplay adapted by Mel Dinelli from his play "The Man" concerns a boa
# Sentiment : NEGATIVE
# Score: 0.9996007084846497
#
# Review : Wow, what an overrated movie this turned out to be! It was supposed to be "an extremely suspenseful
# Sentiment : NEGATIVE
# Score: 0.9715428352355957
#
# Review : I can't believe the high marks people have given this film on this site. The writing is incredibly b
# Sentiment : NEGATIVE
# Score: 0.9997498393058777
#
# Review : Widow hires a psychopath as a handyman. Sloppy film noir thriller which doesn't make much of its ten
# Sentiment : NEGATIVE
# Score: 0.9997617602348328
#
# Review : I have no idea how anyone can give this movie high marks. I didn't rent it thinking it was the next
# Sentiment : NEGATIVE
# Score: 0.9996899366378784
#
# Review : Seeing the title of this movie "Stupid Teenagers Must Die" made me believe this was a spoof of some
# Sentiment : NEGATIVE
# Score: 0.9996392726898193
#
# Review : Now I understand that this took two months to shoot. Really? I'm pretty certain my crew could do it
# Sentiment : NEGATIVE
# Score: 0.9960076808929443
#
# Review : STMD! is not a terrible movie, but it IS quite forgettable. The lighting is intentionally poor in ma
# Sentiment : NEGATIVE
# Score: 0.9994314312934875
#
# Review : Okay, so it was never going to change the world, and it bombed at the box office, but Honky Tonk Fre
# Sentiment : POSITIVE
# Score: 0.9490458965301514
#
# Review : A sprawling, overambitious, plotless comedy that has no dramatic center. It was probably intended to
# Sentiment : NEGATIVE
# Score: 0.9971680045127869
#
# Review : No, no, no, no, no, no, NO! This is not a film, this is an excuse to show people dancing. This is ju
# Sentiment : NEGATIVE
# Score: 0.9997408986091614
#
# Review : I found this movie really hard to sit through, my attention kept wandering off the tv. As far as rom
# Sentiment : NEGATIVE
# Score: 0.9998123049736023
#
# Review : OK, so my summary line is a cheap trick. But the movie is full of them and it gets absurdly praised,
# Sentiment : NEGATIVE
# Score: 0.9994513392448425
#
# Review : An obscure horror show filmed in the Everglades. Two couples stay overnight in a cabin after being m
# Sentiment : NEGATIVE
# Score: 0.9957018494606018
#
# Review : This film is about a couple that decides to take a vacation to The Everglades along with another cou
# Sentiment : NEGATIVE
# Score: 0.9994004964828491
#
# Review : Talented screenwriter Alvin Sargent sadly cannot get any engaging ideas cooking in this artificial t
# Sentiment : NEGATIVE
# Score: 0.9639788866043091
#
# Review : An Italian/American co-production co-starring Linda Blair and David 'The Hoff' Hasselhoff: how could
# Sentiment : NEGATIVE
# Score: 0.9960070252418518
#
# Review : Oh my... bad clothing, worse synth music and the worst: David Hasselhoff. The 80's are back with ven
# Sentiment : POSITIVE
# Score: 0.9776186347007751
#
# Review : There are many different versions of this one floating around, so make sure you can locate one of th
# Sentiment : NEGATIVE
# Score: 0.999340832233429
#
# Review : Witchcraft/Witchery/La Casa 4/ and whatever else you wish to call it. How about..Crud.<br /><br />A
# Sentiment : NEGATIVE
# Score: 0.9990212917327881
#
# Review : "Witchery" might just be the most incoherent and lamentably scripted horror movie of the 80's but, l
# Sentiment : POSITIVE
# Score: 0.7760300040245056
#
# Review : Witchy Hildegard Knef traps a group of people in an isolated hotel and picks them off one by one in
# Sentiment : NEGATIVE
# Score: 0.9987127780914307
#
# Review : A really very bad movie, with a very few good moments or qualities.<br /><br />It starts off with pr
# Sentiment : NEGATIVE
# Score: 0.9995027780532837
#
# Review : This film features two of my favorite guilty pleasures. Sure, the effects are laughable, the story c
# Sentiment : POSITIVE
# Score: 0.9996675252914429
#
# Review : I watched this movie purely for the setting. It was filmed in an old hotel that a friend owns shares
# Sentiment : NEGATIVE
# Score: 0.9207525253295898
#
# Review : This only gets bashed because it stars David Hasselhoff. Well, then let me bash it to. Compared to t
# Sentiment : NEGATIVE
# Score: 0.8179941773414612
#
# Review : We brought this film as a joke for a friend, and could of been our worst joke to play. The film is b
# Sentiment : NEGATIVE
# Score: 0.9998024106025696
#
# Review : Humm, an Italian movie starred by David hasselhoff and Linda Blair, I wasn´t expecting very much, to
# Sentiment : NEGATIVE
# Score: 0.9981067180633545
#
# Review : I and a friend rented this movie. We both found the movie soundtrack and production techniques to be
# Sentiment : NEGATIVE
# Score: 0.9997517466545105
#
# Review : I'm gettin' sick of movies that sound entertaining in a one-line synopsis then end up being equal to
# Sentiment : NEGATIVE
# Score: 0.9994502663612366
#
# Review : Not like I went in expecting a lot out of it, but I was at least hoping for a fun dumb big budget mo
# Sentiment : NEGATIVE
# Score: 0.9995810389518738
#
# Review : That snarl...<br /><br />That scowl...<br /><br />The acts of random violence...<br /><br />The gutt
# Sentiment : NEGATIVE
# Score: 0.999549925327301
#
# Review : generally speaking I don't make negative comments on here. But since this is a festival piece, I don
# Sentiment : NEGATIVE
# Score: 0.9989822506904602
#
# Review : This show should be titled, "When Bad Writing Happens To Good Actors" considering most of the player
# Sentiment : NEGATIVE
# Score: 0.9993749260902405
#
# Review : I thought maybe... maybe this could be good. An early appearance by the Re-Animator (Jeffery Combs);
# Sentiment : NEGATIVE
# Score: 0.9980509281158447
#
# Review : 1983's "Frightmare" is an odd little film. The director seems to be trying to combine the atmosphere
# Sentiment : NEGATIVE
# Score: 0.99793541431427
#
# Review : I don't get it! The teenage leads in "Horror Star" supposedly all are devoted horror fans, yet when
# Sentiment : POSITIVE
# Score: 0.982115626335144
#
# Review : Conrad Radzoff(Ferdy Mayne), a hammy cult icon, dies from a heart ailment(not before disposing of an
# Sentiment : NEGATIVE
# Score: 0.9988896250724792
#
# Review : One of the last surviving horror screen greats - Conrad Radzoff - dies and has his body placed in a
# Sentiment : NEGATIVE
# Score: 0.9826359748840332
#
# Review : My parents used to rent a lot of horror movies when I was a child. We loved watching them even when
# Sentiment : NEGATIVE
# Score: 0.9995515942573547
#
# Review : Frightmare begins with a horror movie icon killing a director and then his servant before he is laid
# Sentiment : NEGATIVE
# Score: 0.9957590699195862
#
# Review : It's Saturday, it's raining, and I think every movie should have at least one comment... so I just w
# Sentiment : NEGATIVE
# Score: 0.9960368275642395
#
# Review : I caught this on IFC last week and I thought it was typical of the indie short subject film: heavy o
# Sentiment : NEGATIVE
# Score: 0.9992363452911377
#
# Review : Acolytes presents an interesting mix of original concepts in "screaming teen" cliché horror with a m
# Sentiment : NEGATIVE
# Score: 0.99839848279953
#
# Review : This was a decent movie for the first half. Too many cheap BOO! moments but the tension builds, the
# Sentiment : NEGATIVE
# Score: 0.9989663362503052
#
# Review : A rather lame teen slasher from Brisbane. While the plot hinges on a fairly decent idea, the writing
# Sentiment : NEGATIVE
# Score: 0.9994650483131409
#
# Review : I was completely bored with this film, melodramatic for no apparent reason. Every thing just becomes
# Sentiment : NEGATIVE
# Score: 0.998873770236969
#
# Review : Art-house horror tries to use unconventional aesthetics to cover the fact that this is just another
# Sentiment : NEGATIVE
# Score: 0.9985059499740601
#
# Review : The film opens with a cult leader attempting to resurrect a dead member with his followers chanting
# Sentiment : NEGATIVE
# Score: 0.9977664947509766
#
# Review : I bought this on VHS as "Terror Hospital", and when I got home I checked IMDb and was like OMG it's
# Sentiment : NEGATIVE
# Score: 0.9806879758834839
#
# Review : This is a hard film to rate. While it truly deserves its 3 (or perhaps even a two), for an Al Adamso
# Sentiment : NEGATIVE
# Score: 0.9937684535980225
#
# Review : I only came here to check Terror Hospital for an alternate title so I'd know what not to pick up. No
# Sentiment : NEGATIVE
# Score: 0.9996300935745239
#
# Review : The first 20 minutes were a little fun because I don't think I've seen a film this bad before {actin
# Sentiment : NEGATIVE
# Score: 0.9997522234916687
#
# Review : This film, which I rented under the title "Black Voodoo" should be avoided. I was expecting a blaxpl
# Sentiment : NEGATIVE
# Score: 0.9997326731681824
#
# Review : Maniratnam, who in India, is often compared with prominent world film makers and is regarded a geniu
# Sentiment : POSITIVE
# Score: 0.8634265065193176
#
# Review : Jacqueline Hyde starts like any other normal day for telemarketing individual Jackie Hyde (co-produc
# Sentiment : NEGATIVE
# Score: 0.9988092184066772
#
# Review : Sorry, but Jacqueline Hyde (get it??? - Jack L and Hyde - Jekyll & Hyde) has some of the worst actin
# Sentiment : NEGATIVE
# Score: 0.9996728897094727
#
# Review : This film seems well made, and more efforts should be made to promote films by women. That aside, th
# Sentiment : NEGATIVE
# Score: 0.9974609613418579
#
# Review : It hurt to watch this movie, it really did... I wanted to like it, even going in. Shot obviously for
# Sentiment : POSITIVE
# Score: 0.9880741238594055
#
# Review : Rita Hayworth is just stunning at times and, for me, the only reason to watch this silly film. Despi
# Sentiment : NEGATIVE
# Score: 0.9905965328216553
#
# Review : Like 'Singin' in the Rain', 'Cover Girl' has a trio of two guys and a girl. In 'Cover Girl', Phil Si
# Sentiment : NEGATIVE
# Score: 0.9936503767967224
#
# Review : Rita Hayworth plays a Brooklyn nightclub dancer named Rusty who specializes in cheesecake chorus rev
# Sentiment : NEGATIVE
# Score: 0.9974156618118286
